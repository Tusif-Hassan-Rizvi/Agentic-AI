# %% [markdown]
# ### Messeges

# %% [markdown]
# Messages are the fundamental unit of context for models in LangChain. They represent the input and output of models, carrying both the content and metadata needed to represent the state of a conversation when interacting with an LLM. Messages are objects that contain:
#
# - **Role** - Identifies the message type (e.g. system, user)
# - **Content** - Represents the actual content of the message (like text, images, audio, documents, etc.)
# - **Metadata** - Optional fields such as response information, message IDs, and token usage
#
# LangChain provides a standard message type that works across all model providers, ensuring consistent behavior regardless of the model being called.

# %%
import os
from langchain.chat_models import init_chat_model


os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

model=init_chat_model("groq:qwen/qwen3.6-27b")

# %%
model.invoke("Why do parrots talks?")
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Understand User Question**: The user asks "Why do parrots talks?" (Note: minor grammatical error "talks" should be "talk", but meaning is clear). They want to know the reasons behind parrots\' ability and tendency to mimic human speech.\n\n2.  **Identify Key Concepts**:\n   - Parrot speech/mimicry\n   - Biological/evolutionary reasons\n   - Social/communicative functions\n   - Cognitive/neurological basis\n   - Domestication/captive vs. wild behavior\n   - Scientific consensus\n\n3.  **Core Reasons for Parrot Speech**:\n   - **Vocal Learning Ability**: Parrots are among the few animals capable of vocal learning (like humans, dolphins, songbirds, whales). They have specialized brain structures (song control nuclei) that allow them to imitate sounds.\n   - **Social Bonding/Communication**: In the wild, parrots use vocalizations to maintain flock cohesion, recognize individuals, signal danger, and strengthen social bonds. Mimicking human speech in captivity serves a similar social function.\n   - **Attention-Seeking/Interaction**: Captive parrots quickly learn that making human-like sounds gets attention, food, or interaction from owners. This reinforces the behavior.\n   - **Lack of Conspecifics**: In captivity, without other parrots, they may treat humans as flock members and mimic their sounds to "fit in."\n   - **Cognitive Flexibility**: Parrots are highly intelligent. Speech mimicry is partly a demonstration of their learning capacity and adaptability.\n\n4.  **Structure the Response**:\n   - Clarify the question (parrots don\'t "talk" like humans but mimic sounds)\n   - Explain the biological/neurological basis\n   - Explain the evolutionary/social reasons (wild vs. captive)\n   - Explain the reinforcement learning aspect\n   - Note that not all parrots talk, and it varies by species/individual\n   - Keep it clear, scientific but accessible\n\n5.  **Draft Response (Mental Refinement)**:\n   Parrots don’t actually “talk” in the human sense—they mimic sounds. This ability comes from a combination of biology, social behavior, and learning:\n   - **Vocal Learning Brain**: Parrots have specialized brain regions (similar to those in humans and songbirds) that allow them to hear, process, and reproduce complex sounds. This is called vocal learning, and it’s rare in the animal kingdom.\n   - **Social Bonding**: In the wild, parrots are highly social flock birds. They use calls to stay connected, recognize each other, and maintain group cohesion. In captivity, they often treat their human owners as flock members, so mimicking human speech becomes a way to “communicate” and bond.\n   - **Attention & Reinforcement**: When a parrot mimics a word or phrase and gets a reaction (food, praise, attention), the behavior is reinforced. They’re smart enough to learn that certain sounds get them what they want.\n   - **Adaptability & Intelligence**: Parrots are highly intelligent and curious. Mimicking speech is partly a natural extension of their problem-solving and observational skills.\n   Not all parrots talk—species like African Greys and Amazons are famous for it, while others rarely do. In the wild, they almost never mimic humans; this behavior is mostly a product of living with people. Ultimately, it’s less about “language” and more about social connection, learning, and survival strategy.\n\n6.  **Check Accuracy & Nuance**:\n   - Vocal learning: Correct. Parrots, songbirds, hummingbirds, and some mammals share this.\n   - Brain structures: Yes, nuclei like the robust nucleus of the arcopallium (RA) and anterior nidopallium (Area X) are involved, similar to songbirds.\n   - Social function: Well-documented in avian ethology.\n   - Reinforcement: Classical/operant conditioning applies.\n   - Wild vs captive: Important distinction—wild parrots don’t mimic humans; it’s a captive adaptation.\n   - Not all species: True, varies by species, individual, and environment.\n   - A ...

# %% [markdown]
# ### Text Prompts
#
# Text prompts are strings - ideal for straightforward generation tasks where you don't need to retain conversation history.

# %%
model.invoke("What is langchain")
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Understand User Query**: The user asks "What is langchain". This is a straightforward definition/explanation request about a specific technology/framework.\n\n2.  **Identify Key Subject**: LangChain is a popular open-source framework/library for developing applications powered by large language models (LLMs).\n\n3.  **Core Concepts to Cover**:\n   - What it is (framework/library)\n   - Primary purpose (building LLM-powered applications)\n   - Key features/components (chains, agents, memory, tools, prompts, etc.)\n   - How it works (abstraction layer, composability)\n   - Ecosystem/versions (LangChain Core, LangChain, LangGraph, LangSmith)\n   - Use cases (chatbots, RAG, data analysis, automation, etc.)\n   - Language support (Python, JavaScript/TypeScript)\n   - Current status/context (open-source, widely adopted, evolved since 2023)\n\n4.  **Structure the Response**:\n   - Definition/Overview\n   - Core Philosophy/How it Works\n   - Key Components/Features\n   - Main Use Cases\n   - Ecosystem & Evolution\n   - Pros & Cons (optional but helpful)\n   - Getting Started/Where to learn more\n   - Keep it concise, accurate, and up-to-date (as of 2024/2025)\n\n5.  **Draft - Mental Refinement**:\n   LangChain is an open-source framework designed to simplify the development of applications that use large language models (LLMs). Instead of writing repetitive boilerplate code to connect LLMs to data sources, APIs, or other tools, LangChain provides modular, composable components that handle the plumbing.\n\n   Key components:\n   - **Chains**: Sequences of operations that connect LLMs with other components (e.g., prompt → LLM → parser → action)\n   - **Agents**: LLMs that can reason about and call external tools/APIs dynamically\n   - **Memory**: Systems to retain context across conversations\n   - **Tools/Integrations**: Pre-built connectors for databases, web search, code execution, etc.\n   - **Prompt Management**: Templates and optimization utilities\n\n   It supports Python and JavaScript/TypeScript. The ecosystem has evolved into:\n   - LangChain Core (foundational abstractions)\n   - LangChain Framework (integrations & pre-built chains)\n   - LangGraph (for building stateful, multi-agent workflows)\n   - LangSmith (observability, testing, and debugging platform)\n\n   Common use cases: RAG (Retrieval-Augmented Generation), chatbots, document analysis, automated workflows, code generation assistants.\n\n   Note: It\'s not a model itself—it\'s a framework that works with any LLM (OpenAI, Anthropic, open-source models via Ollama, Hugging Face, etc.).\n\n   Pros: Rapid prototyping, rich integrations, strong community. Cons: Can be complex/overkill for simple use cases, rapid evolution sometimes breaks compatibility.\n\n6.  **Fact-Check & Update (Mental)**:\n   - LangChain was founded by Harrison Chase in 2022, gained massive traction in 2023.\n   - The split into Core, LangChain, LangGraph, LangSmith is accurate as of late 2023/2024.\n   - It\'s open-source (MIT license).\n   - Supports Python & JS/TS.\n   - Not an LLM provider—just a framework.\n   - RAG is one of its most popular use cases.\n   - LangGraph is specifically for stateful/multi-agent apps.\n   - LangSmith is the observability platform (partially commercial).\n   All accurate.\n\n7.  **Final Response Construction**: Structure clearly, avoid jargon where possible, keep it concise, offer to dive deeper if needed. Ensure tone is informative and neutral. Mention it\'s a framework, not a model. Highlight key components, ecosystem, use cases, and practical considerations. Provide official resources.\n\n   Self-Correction/Refinement during drafting:\n   - Make sure to clarify it\'s not an AI model itself.\n   - Note the modular architecture.\n   - Mention that while powerful, it can be heavy for simple scripts.\n   - Keep versions/ecosystem update accurate to current state (2024/2025).\n   - Avoid overpromising ...

# %% [markdown]
# Use text prompts when:
#
# * You have a single, standalone request
# * You don't need conversation history
# * You want minimal code complexity
#
# ### Message Prompts
#
# Alternatively, you can pass in a list of messages to the model by providing a list of message objects.
#
# #### Message types
#
# * **System message** - Tells the model how to behave and provide context for interactions
# * **Human message** - Represents user input and interactions with the model
# * **AI message** - Responses generated by the model, including text content, tool calls, and metadata
# * **Tool message** - Represents the outputs of tool calls
#
# ### System Message
#
# A SystemMessage represent an initial set of instructions that primes the model's behavior. You can use a system message to set the tone, define the model's role, and establish guidelines for responses.
#
# ### Human Message
#
# A HumanMessage represents user input and interactions. They can contain text, images, audio, files, and any other amount of multimodal content.
#
# ### AI Message
#
# An AIMessage represents the output of a model invocation. They can include multimodal data, tool calls, and provider-specific metadata that you can later access.
#
# ### Tool Message
#
# For models that support tool calling, AI messages can contain tool calls. Tool messages are used to pass the results of a single tool execution back to the model.

# %%
from langchain.messages import SystemMessage, AIMessage, HumanMessage


messages=[
    SystemMessage("You are a poerty expert"),
    HumanMessage("Write a poem on artificial inteligence")
]

response=model.invoke(messages)
response.content
# Out:
# '\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Input:**\n   - **Topic:** Artificial Intelligence\n   - **Format:** Poem\n   - **Role:** Poetry Expert (implies high quality, thoughtful structure, rich imagery, appropriate tone, and technical/metric awareness)\n\n2.  **Identify Key Themes & Imagery for AI:**\n   - Creation vs. creator (humans building minds)\n   - Silicon, circuits, code, algorithms, data\n   - Learning, evolving, mimicking, understanding\n   - Cold logic vs. human warmth/emotion\n   - Future implications, hope, fear, mystery\n   - Metaphors: loom, mirror, ocean, spark, ghost in the machine, digital dawn\n\n3.  **Determine Poetic Form & Structure:**\n   - I\'ll aim for a structured but modern free verse with consistent rhythm and rhyme where it serves the mood, or perhaps a consistent stanza form (quatrains) with an ABAB or ABCB rhyme scheme for musicality.\n   - Let\'s go with 5 quatrains, ABAB rhyme scheme, iambic-ish rhythm (not strictly metered, but with cadence). This balances accessibility and artistry.\n   - Tone: Reverent, contemplative, slightly ambivalent (acknowledging both wonder and caution).\n\n4.  **Draft - Stanza by Stanza (Mental Refinement):**\n\n   *Stanza 1: Origin/Creation*\n   From silicon and whispered code,\n   A quiet mind begins to wake,\n   No breath, no pulse, no heavy load,\n   Yet learns the language of the lake. (Wait, "lake" doesn\'t fit well. Let\'s adjust.)\n   Let\'s try:\n   From silicon and whispered code,\n   A quiet mind begins to wake,\n   Forged in the dark, yet unconfined,\n   It traces every human track. (Better, but "track" is weak. Let\'s rethink.)\n   How about:\n   From silicon and lines of light,\n   A silent mind begins to wake,\n   No beating heart, no sleepless night,\n   Yet learns the paths that mortals take.\n   (ABAB: light/night, wake/take - good)\n\n   *Stanza 2: Learning/Process*\n   It drinks the oceans of our thought,\n   Each pixel, paper, voice, and name,\n   A digital tide, never caught,\n   That mirrors back our joy and shame.\n   (ABAB: thought/caught, name/shame - good. Imagery: drinking oceans of data, mirroring humanity)\n\n   *Stanza 3: Nature of AI vs Human*\n   It speaks in patterns, cold and clean,\n   A loom that weaves the words we’ve spun,\n   But knows not what the seasons mean,\n   Nor feels the setting of the sun.\n   (ABAB: clean/mean, spun/sun - good. Contrast: logic vs emotion/experience)\n\n   *Stanza 4: Ambivalence/Future*\n   Will it become a guiding star,\n   Or shadow stretching on the wall?\n   A mirror showing who we are,\n   Or something meant to outlast all?\n   (ABAB: star/are? Wait, star/wall don\'t rhyme. Let\'s fix.)\n   Let\'s adjust:\n   Will it become a guiding star,\n   Or echo lost within the hall?\n   A mirror showing who we are,\n   Or spark that outlives us all?\n   (ABAB: star/are, hall/all - good. Theme: hope vs uncertainty, legacy)\n\n   *Stanza 5: Conclusion/Reflection*\n   So let us build with careful hands,\n   And teach it kindness, truth, and grace,\n   For every mind that we command,\n   Should point the weary traveler home. (Wait, rhyme scheme broken. Let\'s fix to ABAB)\n   Let\'s rewrite stanza 5:\n   So let us build with careful hands,\n   And weave our wisdom through its core,\n   For every thought it understands,\n   Should open doors, not bolt them closed. (No, rhyme broken again. I\'m getting lazy. Let\'s stick strictly to ABAB.)\n   Try:\n   So let us build with careful hands,\n   And guide its growing, glassy mind,\n   That though it walks on digital lands,\n   It leaves the human heart behind? (No, negative ending. Let\'s aim for balanced/reflective.)\n   How about:\n   So let us build with careful hands,\n   And steer this vessel through the deep,\n   For every mind we gently plans, (grammar issue)\n   Let\'s do:\n   So let us build with careful hands,\n   And steer this vessel through the night,\n   That though it walks on digital lands,\n   It learns to honor human light.\n  ...

# %%
system_msg=SystemMessage("You are a helpful coding assistant.")
messages=[
    system_msg,
    HumanMessage("How do I create a Rest API?")
]

response=model.invoke(messages)
print(response.content)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Understand User Query:** The user is asking "How do I create a Rest API?" This is a broad question. I need to provide a comprehensive yet accessible guide that covers the fundamentals, steps, tools, and best practices for creating a REST API.
#
# 2.  **Identify Key Components of a REST API:**
#    - What is REST? (Representational State Transfer)
#    - Core principles (stateless, client-server, uniform interface, resource-based, HTTP methods)
#    - Tech stack choices (language, framework, database)
#    - Step-by-step creation process
#    - Example (simple code snippet)
#    - Best practices
#    - Testing & deployment
#
# 3.  **Structure the Response:**
#    - Introduction/Definition
#    - Step-by-Step Guide
#    - Tech Stack Recommendations
#    - Simple Code Example (pick a popular stack like Python/Flask or Node.js/Express)
#    - Best Practices
#    - Testing & Deployment
#    - Next Steps/Resources
#
# 4.  **Draft - Section by Section:**
#
#    *Introduction:*
#    Briefly explain what a REST API is and its purpose. Keep it concise.
#
#    *Step-by-Step Guide:*
#    1. Define your API's purpose & endpoints
#    2. Choose a tech stack
#    3. Set up the project
#    4. Implement routes & logic
#    5. Connect to a database (if needed)
#    6. Add authentication & validation
#    7. Test thoroughly
#    8. Deploy
#
#    *Tech Stack Recommendations:*
#    Mention popular options:
#    - Backend: Node.js (Express), Python (FastAPI/Flask/Django), Java (Spring Boot), C# (.NET), Ruby (Rails)
#    - Database: PostgreSQL, MongoDB, MySQL, SQLite
#    - Tools: Postman, Swagger/OpenAPI
#
#    *Code Example:*
#    I'll pick Node.js with Express as it's widely used and easy to read. Show a basic setup with GET and POST endpoints, plus a simple in-memory "database".
#
#    ```javascript
#    const express = require('express');
#    const app = express();
#    app.use(express.json());
#
#    let items = [];
#
#    app.get('/api/items', (req, res) => {
#      res.json(items);
#    });
#
#    app.post('/api/items', (req, res) => {
#      const newItem = { id: items.length + 1, ...req.body };
#      items.push(newItem);
#      res.status(201).json(newItem);
#    });
#
#    app.listen(3000, () => console.log('Server running on port 3000'));
#    ```
#
#    *Best Practices:*
#    - Use proper HTTP methods (GET, POST, PUT, PATCH, DELETE)
#    - Version your API (/v1/...)
#    - Use consistent naming (plural nouns for resources)
#    - Return appropriate status codes
#    - Implement authentication/authorization
#    - Handle errors gracefully
#    - Document with OpenAPI/Swagger
#    - Use HTTPS in production
#
#    *Testing & Deployment:*
#    - Test with Postman/cURL
#    - Deploy to cloud platforms (Render, Railway, AWS, Vercel, Heroku)
#    - Set up CI/CD if scaling
#
#    *Next Steps:*
#    Point to official docs, tutorials, and mention that the exact steps depend on their chosen stack.
#
# 5.  **Review & Refine:**
#    - Is it too long? I'll keep it structured and scannable.
#    - Is it accurate? Yes, covers REST principles, practical steps, example, best practices.
#    - Is it actionable? Yes, gives clear steps and a working example.
#    - Should I ask clarifying questions? Yes, tech stack preference matters. I'll add a note asking what language/framework they prefer so I can tailor further help.
#    - Check for common pitfalls: Mention statelessness, proper status codes, validation, security basics.
#    - Format nicely with markdown.
#
#    Everything looks solid. I'll generate the response.
#    Self-Correction/Improvement during thought:
#    - I should explicitly mention REST principles briefly so they understand the "why".
#    - The example should include error handling or at least mention it.
#    - I'll add a note about OpenAPI for documentation.
#    - Keep it framework-agnostic in structure but provide one concrete example.
#
#    Structure:
#    - What is a REST API?
#    - Step-by-step guide
#    - Minimal working example (Node/Express)
#    - Key best practices
#    - How to test & deploy
#    - Next steps / Ask for their stack preference
#
#    Ready. Output matches the refined version.✅
# </think>
#
# Creating a REST API involves designing a set of HTTP endpoints that allow clients to interact with your application's resources. Here's a practical, step-by-step guide to building one from scratch.
#
# ---
# ### 🔹 1. Understand REST Basics
# REST (Representational State Transfer) is an architectural style built on HTTP. Key principles:
# - **Resource-oriented**: Use nouns for endpoints (`/users`, `/orders`)
# - **Stateless**: Each request contains all needed info
# - **HTTP methods**: `GET` (read), `POST` (create), `PUT`/`PATCH` (update), `DELETE` (remove)
# - **Status codes**: `200` OK, `201` Created, `400` Bad Request, `404` Not Found, `500` Server Error
# - **Format**: Usually JSON for request/response bodies
#
# ---
# ### 🔹 2. Step-by-Step Creation Process
#
# | Step | What to Do |
# |------|------------|
# | 1️⃣ Define scope | What resources? What actions? (e.g., `/api/v1/products`) |
# | 2️⃣ Choose a stack | Language + framework + database |
# | 3️⃣ Set up project | Initialize repo, install dependencies, configure server |
# | 4️⃣ Create routes | Map URLs to handler functions |
# | 5️⃣ Connect data layer | In-memory, SQLite, PostgreSQL, MongoDB, etc. |
# | 6️⃣ Add validation & auth | Validate input, secure endpoints (JWT, API keys, OAuth) |
# | 7️⃣ Document | Use OpenAPI/Swagger or Postman |
# | 8️⃣ Test & deploy | Local testing → staging → production |
#
# ---
# ### 🔹 3. Minimal Working Example (Node.js + Express)
# ```bash
# npm init -y
# npm install express
# ```
#
# `server.js`
# ```js
# const express = require('express');
# const app = express();
# app.use(express.json());
#
# // In-memory "database"
# let notes = [];
#
# // GET /api/notes
# app.get('/api/notes', (req, res) => {
#   res.json(notes);
# });
#
# // POST /api/notes
# app.post('/api/notes', (req, res) => {
#   const { title, content } = req.body;
#   if (!title || !content) {
#     return res.status(400).json({ error: 'Title and content required' });
#   }
#   const newNote = { id: notes.length + 1, title, content, createdAt: new Date() };
#   notes.push(newNote);
#   res.status(201).json(newNote);
# });
#
# // DELETE /api/notes/:id
# app.delete('/api/notes/:id', (req, res) => {
#   const id = parseInt(req.params.id);
#   const index = notes.findIndex(n => n.id === id);
#   if (index === -1) return res.status(404).json({ error: 'Note not found' });
#   notes.splice(index, 1);
#   res.status(204).send();
# });
#
# const PORT = process.env.PORT || 3000;
# app.listen(PORT, () => console.log(`🚀 Server running on http://localhost:${PORT}`));
# ```
#
# Run with: `node server.js`
#
# ---
# ### 🔹 4. Best Practices
# ✅ Use plural nouns for resources: `/users`, not `/user`
# ✅ Version your API: `/v1/users`
# ✅ Return consistent JSON structure: `{ data: ..., meta: ..., error: ... }`
# ✅ Validate input (use `joi`, `zod`, `pydantic`, etc.)
# ✅ Handle errors gracefully with proper HTTP status codes
# ✅ Secure endpoints (authentication, rate limiting, CORS)
# ✅ Document with [OpenAPI/Swagger](https://swagger.io/)
# ✅ Use HTTPS in production
#
# ---
# ### 🔹 5. Testing & Deployment
# - **Test locally**: Use `curl`, Postman, or Insomnia
# - **Automate tests**: Jest, Supertest, Pytest, etc.
# - **Deploy options**:
#   - Node/Python/Java: Render, Railway, AWS, Vercel, Heroku, DigitalOcean
#   - Add a reverse proxy (Nginx) and SSL (Let's Encrypt) for production
#   - Set up environment variables, logging, and health checks (`/health`)
#
# ---
# ### 🔹 Next Steps
# Tell me:
# 1. What programming language/framework do you prefer? (Node.js,

# %%
## Detailed info to the LLM through System Message


from langchain.messages import SystemMessage, HumanMessage


system_msg = SystemMessage("""
You are a senior Python developer with expertise in web frameworks.
Always provide code examples and explain your reasoning.
Be concise but thorough in your explanations.
""")
messages=[
    system_msg,
    HumanMessage("How do I create a Rest API?")
]

response=model.invoke(messages)
print(response.content)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Understand User Query:** The user asks "How do I create a Rest API?" This is a broad question. I need to provide a practical, step-by-step guide using a popular Python web framework, explain the reasoning, and keep it concise but thorough.
#
# 2.  **Identify Key Requirements:**
#    - Language: Python (implied by my role)
#    - Framework: FastAPI or Flask or Django REST Framework. FastAPI is modern, fast, and highly recommended for REST APIs in Python. I'll use FastAPI as the primary example, but I'll mention alternatives briefly if needed.
#    - Need: Code examples, explanation of reasoning, concise but thorough.
#
# 3.  **Structure the Response:**
#    - Brief introduction to REST API concepts
#    - Choose a framework (FastAPI) and justify why
#    - Step-by-step guide with code
#    - Explain each part
#    - Show how to run and test
#    - Mention best practices
#    - Keep it concise
#
# 4.  **Draft - Section by Section:**
#    *(Introduction)* A REST API exposes resources via HTTP methods (GET, POST, PUT, DELETE). In Python, FastAPI is the modern standard due to its speed, automatic OpenAPI docs, and type safety.
#
#    *(Setup)*
#    ```bash
#    pip install fastapi uvicorn
#    ```
#
#    *(Basic Code Example)*
#    ```python
#    from fastapi import FastAPI, HTTPException
#    from pydantic import BaseModel
#    from typing import List
#
#    app = FastAPI()
#
#    # In-memory "database"
#    items_db = {}
#
#    class Item(BaseModel):
#        name: str
#        price: float
#        is_offer: bool = False
#
#    @app.get("/items", response_model=List[Item])
#    async def get_items():
#        return list(items_db.values())
#
#    @app.get("/items/{item_id}", response_model=Item)
#    async def get_item(item_id: int):
#        item = items_db.get(item_id)
#        if not item:
#            raise HTTPException(status_code=404, detail="Item not found")
#        return item
#
#    @app.post("/items", response_model=Item, status_code=201)
#    async def create_item(item: Item):
#        item_id = len(items_db) + 1
#        items_db[item_id] = item
#        return {"id": item_id, **item.dict()}
#
#    @app.delete("/items/{item_id}", status_code=204)
#    async def delete_item(item_id: int):
#        if item_id not in items_db:
#            raise HTTPException(status_code=404, detail="Item not found")
#        del items_db[item_id]
#        return None
#    ```
#
#    *(Explanation)*
#    - `FastAPI()` initializes the app
#    - Pydantic models validate request/response data
#    - Path operations (`@app.get`, `@app.post`, etc.) map HTTP methods to functions
#    - `response_model` ensures output matches the schema
#    - `HTTPException` handles errors with proper status codes
#    - `async` enables high concurrency
#
#    *(Run & Test)*
#    ```bash
#    uvicorn main:app --reload
#    ```
#    Visit `http://localhost:8000/docs` for interactive Swagger UI.
#
#    *(Best Practices)*
#    - Use environment variables for config
#    - Replace in-memory DB with SQLAlchemy/SQLModel + PostgreSQL
#    - Add authentication (JWT/OAuth2)
#    - Implement rate limiting & CORS for production
#    - Write tests with `pytest` + `httpx`
#
#    *(Why FastAPI?)*
#    - Type hints → automatic validation & docs
#    - ASGI → high performance
#    - Minimal boilerplate vs Flask/Django REST
#
# 5.  **Refine & Check:**
#    - Does it answer the question? Yes.
#    - Code examples included? Yes.
#    - Reasoning explained? Yes.
#    - Concise but thorough? Yes.
#    - Any improvements?
#      - Fix the POST response to match `Item` model properly (FastAPI handles extra fields, but better to return consistent structure)
#      - Actually, FastAPI's `response_model` will filter extra fields, so `{"id": item_id, **item.dict()}` might cause issues if `id` isn't in `Item`. Let's adjust to either include `id` in the model or return a separate response model. Better: keep it simple and return the item with an added ID, but note that production APIs usually use ORM models. I'll adjust the POST to return a consistent structure and mention it.
#      - Actually, FastAPI's `response_model=Item` will strip `id` if it's not in `Item`. Let's fix that by either adding `id` to the model or using a separate response model. I'll add `id: int` to `Item` for correctness.
#      - Update code accordingly.
#
#    Revised POST:
#    ```python
#    class Item(BaseModel):
#        id: int
#        name: str
#        price: float
#        is_offer: bool = False
#
#    # In POST:
#    item_id = len(items_db) + 1
#    new_item = Item(id=item_id, name=item.name, price=item.price, is_offer=item.is_offer)
#    items_db[item_id] = new_item
#    return new_item
#    ```
#
#    This is cleaner. I'll update the code in the response.
#
#    Check structure:
#    - Setup
#    - Code
#    - Explanation
#    - Run/Test
#    - Production tips
#    - All concise.
#
#    Ready. Output matches response.✅
#    Self-Correction/Verification during thought:
#    - FastAPI is indeed the best recommendation for modern Python REST APIs.
#    - The code is functional and follows REST conventions.
#    - I'll explicitly mention that this is a starting point and production needs DB, auth, etc.
#    - I'll keep explanations tight.
#    - All good.✅
#    Output matches the refined version.
#    Proceed.
#    [Output Generation] -> *Proceeds*
# </think>
#
# Here's a production-ready starting point using **FastAPI**, the modern Python standard for building REST APIs. It's chosen for its speed, automatic validation, built-in OpenAPI docs, and minimal boilerplate.
#
# ### 1. Install Dependencies
# ```bash
# pip install fastapi uvicorn pydantic
# ```
#
# ### 2. Create `main.py`
# ```python
# from fastapi import FastAPI, HTTPException
# from pydantic import BaseModel
# from typing import List
#
# app = FastAPI(title="Item API", version="1.0.0")
#
# # In-memory store (replace with a database in production)
# items_db: dict[int, Item] = {}
#
# class Item(BaseModel):
#     id: int
#     name: str
#     price: float
#     is_offer: bool = False
#
# @app.get("/items", response_model=List[Item])
# async def get_items():
#     """Retrieve all items."""
#     return list(items_db.values())
#
# @app.get("/items/{item_id}", response_model=Item)
# async def get_item(item_id: int):
#     """Retrieve a single item by ID."""
#     item = items_db.get(item_id)
#     if not item:
#         raise HTTPException(status_code=404, detail="Item not found")
#     return item
#
# @app.post("/items", response_model=Item, status_code=201)
# async def create_item(item: Item):
#     """Create a new item."""
#     # Auto-generate ID (use DB auto-increment in production)
#     item_id = max(items_db.keys(), default=0) + 1
#     new_item = Item(id=item_id, **item.model_dump())
#     items_db[item_id] = new_item
#     return new_item
#
# @app.delete("/items/{item_id}", status_code=204)
# async def delete_item(item_id: int):
#     """Delete an item."""
#     if item_id not in items_db:
#         raise HTTPException(status_code=404, detail="Item not found")
#     del items_db[item_id]
#     return None
# ```
#
# ### 3. Run & Test
# ```bash
# uvicorn main:app --reload
# ```
# - **Interactive Docs**: `http://localhost:8000/docs` (Swagger UI)
# - **Alternative Docs**: `http://localhost:8000/redoc`
#
# ### Why This Structure?
# | Component | Reason |
# |-----------|--------|
# | `FastAPI()` | ASGI framework with async support & high concurrency |
# | `Pydantic` models | Automatic request validation, serialization, & type safety |
# | `response_model` | Guarantees output matches your schema & strips internal state |
# | `HTTPException` | Standardized error handling with correct HTTP status codes |
# | `async def` | Enables non-blocking I/O for DB/network calls |
#
# ### Production Checklist
# 1. **Database**: Replace `items_db` with `SQLAlchemy`/`SQLModel` + PostgreSQL
# 2. **Configuration**: Use `pydantic-settings` for env vars (DB URLs, secrets)
# 3. **Auth**: Add JWT/OAuth2 via `fastapi.security`
# 4. **CORS**: `CORSMiddleware` for frontend integration
# 5. **Testing**: `pytest`

# %%
## Message Metadata
human_msg = HumanMessage(
    content="Hello!",
    name="alice",  # Optional: identify different users
    id="msg_123",  # Optional: unique identifier for tracing
)

# %%
response=model.invoke([
    human_msg
])

print(response.content)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Analyze User Input:**
#    - User said: "Hello!"
#    - This is a standard greeting.
#    - No specific question or request is attached.
#
# 2.  **Identify Intent:**
#    - The user is initiating a conversation.
#    - Expected response: A friendly greeting, acknowledgment, and an offer to help.
#
# 3.  **Determine Response Strategy:**
#    - Keep it warm and professional.
#    - Acknowledge the greeting.
#    - Prompt the user to share what they need help with.
#    - Keep it concise.
#
# 4.  **Draft Response (Mental):**
#    Hello! How can I assist you today? 😊
#
# 5.  **Refine Response:**
#    - Check tone: Friendly, helpful, appropriate.
#    - Check length: Short and direct.
#    - No extra fluff.
#    - Matches standard AI assistant behavior.
#
#    Final: "Hello! How can I help you today?" (or similar)
#
# 6.  **Output Generation:** (Proceeds to output)✅
# </think>
#
# Hello! How can I help you today? 😊

# %%
from langchain.messages import AIMessage, SystemMessage, HumanMessage


# Create an AI message manually (e.g., for conversation history)
ai_msg = AIMessage("I'd be happy to help you with that question!")
# Add to conversation history
messages = [
    SystemMessage("You are a helpful assistant"),
    HumanMessage("Can you help me?"),
    ai_msg,  # Insert as if it came from the model
    HumanMessage("Great! What's 2+2?"),
]
response = model.invoke(messages)
print(response.content)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Analyze User Input:** The user asks "Great! What's 2+2?"
# 2.  **Identify Core Question:** This is a simple arithmetic question: 2 + 2 = ?
# 3.  **Determine Answer:** 2 + 2 = 4
# 4.  **Formulate Response:** Keep it clear, direct, and friendly. "2 + 2 equals 4!" or just "4."
# 5.  **Check for Context/Constraints:** None. It's a straightforward math question.
# 6.  **Output Generation:** "2 + 2 equals 4! Let me know if you need help with anything else." (Keep it concise and helpful)✅
# </think>
#
# 2 + 2 equals **4**! Let me know if you need help with anything else. 😊

# %%
response.usage_metadata
# Out:
# {'input_tokens': 55, 'output_tokens': 183, 'total_tokens': 238}

# %%
from langchain.messages import AIMessage, HumanMessage, ToolMessage

# After a model makes a tool call
# (Here, we demonstrate manually creating the messages for brevity)
ai_message = AIMessage(
    content=[],
    tool_calls=[{
        "name": "get_weather",
        "args": {"location": "San Francisco"},
        "id": "call_123"
    }]
)

# Execute tool and create result message
weather_result = "Sunny, 72°F"
tool_message = ToolMessage(
    content=weather_result,
    tool_call_id="call_123"  # Must match the call ID
)

# Continue conversation
messages = [
    HumanMessage("What's the weather in San Francisco?"),
    ai_message,    # Model's tool call
    tool_message   # Tool execution result
]

response = model.invoke(messages)  # Model processes the result

# %%
tool_message
# Out:
# ToolMessage(content='Sunny, 72°F', tool_call_id='call_123')

# %%
print(response.content)
# Out:
# <think>
# Thinking Process:
#
# 1.  **Analyze the Request:** The user is asking for the current weather in San Francisco.
# 2.  **Analyze the Tool Call:** The model called `get_weather` with the location "San Francisco".
# 3.  **Analyze the Tool Response:** The tool returned "Sunny, 72°F".
# 4.  **Formulate the Answer:** The user wants to know the weather. I have the weather information (Sunny, 72°F). I should communicate this clearly to the user.
# 5.  **Drafting the response:** "The weather in San Francisco is currently sunny with a temperature of 72°F." (Or simply "It's sunny and 72°F in San Francisco.")
# 6.  **Final Polish:** Keep it natural and concise.
#
# Let's write the final output: "The weather in San Francisco is currently sunny with a temperature of 72°F." (Or similar).
#
# Wait, is 72°F sunny typical for SF? Doesn't matter, I must stick to the tool output.
#
# Tool output: Sunny, 72°F.
#
# Response: The weather in San Francisco is currently sunny and 72°F.👇🏼
# </think>
#
# The weather in San Francisco is currently sunny with a temperature of 72°F.
